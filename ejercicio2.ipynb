# %% [markdown]
# # SISD

# %%
import numpy as np
import time

# Creamos dos arrays grandes
a = np.random.rand(10000)
b = np.random.rand(10000)
c = np.empty(10000)

start = time.time()
for i in range(10000):
    c[i] = a[i] + b[i]
end = time.time()

print("Tiempo con bucle for:", end - start, "segundos")
# Out:
# Tiempo con bucle for: 0.003182649612426758 segundos

# %% [markdown]
# # SIMD

# %%
start = time.time()
c = a + b  # Esta operación se realiza en paralelo internamente
end = time.time()

print("Tiempo con NumPy vectorizado:", end - start, "segundos")
# Out:
# Tiempo con NumPy vectorizado: 0.0030252933502197266 segundos

# %% [markdown]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Usaremos los datos generados en el ejemplo anterior
# # Para simplificar, recreamos un conjunto similar pero más pequeño
#
# # Generar 500 registros de logs simulados
# np.random.seed(42)
#
# # Lista de eventos de seguridad
# eventos = ['login_success', 'login_failure', 'file_access', 'admin_login',
#            'password_change', 'firewall_block', 'suspicious_activity',
#            'malware_detected', 'port_scan']
#
# # Generar timestamps para una semana
# fechas = pd.date_range(start='2023-01-01', periods=7)
# timestamps = []
# for fecha in fechas:
#     for hora in range(24):
#         for _ in range(3):  # 3 eventos por hora aprox
#             timestamps.append(fecha + pd.Timedelta(hours=hora) +
#                              pd.Timedelta(minutes=np.random.randint(60)))
#
# # Ajustar al número de registros deseados
# timestamps = timestamps[:500]
#
# # Generar IPs aleatorias
# def random_ip():
#     return f"{np.random.randint(1, 256)}.{np.random.randint(1, 256)}.{np.random.randint(1, 256)}.{np.random.randint(1, 256)}"
#
# # Usuarios del sistema
# usuarios = ['admin', 'user1', 'user2', 'user3', 'system', 'guest', None]
#
# # Generar datos simulados
# data = {
#     'timestamp': timestamps,
#     'ip_origen': [random_ip() for _ in range(500)],
#     'evento': np.random.choice(eventos, 500, p=[0.3, 0.2, 0.2, 0.05, 0.05, 0.08, 0.07, 0.03, 0.02]),
#     'usuario': np.random.choice(usuarios, 500, p=[0.1, 0.2, 0.2, 0.2, 0.1, 0.1, 0.1]),
#     'severidad': np.random.choice(['low', 'medium', 'high', 'critical'], 500, p=[0.5, 0.3, 0.15, 0.05]),
#     'exitoso': np.random.choice([True, False], 500, p=[0.8, 0.2]),
# }
#
# # Crear DataFrame
# logs_df = pd.DataFrame(data)
#
# # Configurar timestamp como índice
# logs_df['timestamp'] = pd.to_datetime(logs_df['timestamp'])
# logs_df = logs_df.sort_values('timestamp')
#
# # Ahora creamos las visualizaciones
# plt.figure(figsize=(15, 10))
#
# # 1. Distribución de eventos por tipo
# plt.subplot(2, 2, 1)
# eventos_count = logs_df['evento'].value_counts()
# sns.barplot(x=eventos_count.index, y=eventos_count.values)
# plt.xticks(rotation=45, ha='right')
# plt.title('Distribución de Eventos por Tipo')
# plt.tight_layout()
#
# # 2. Distribución de eventos por severidad
# plt.subplot(2, 2, 2)
# severidad_count = logs_df['severidad'].value_counts()
# colors = {'low': 'green', 'medium': 'blue', 'high': 'orange', 'critical': 'red'}
# plt.pie(severidad_count, labels=severidad_count.index, autopct='%1.1f%%',
#         colors=[colors[sev] for sev in severidad_count.index])
# plt.title('Distribución de Eventos por Severidad')
#
# # 3. Actividad por hora del día
# plt.subplot(2, 2, 3)
# logs_df['hour'] = logs_df['timestamp'].dt.hour
# hourly_count = logs_df.groupby('hour').size()
# sns.lineplot(x=hourly_count.index, y=hourly_count.values)
# plt.title('Actividad por Hora del Día')
# plt.xlabel('Hora')
# plt.ylabel('Número de Eventos')
#
# # 4. Eventos por día y por severidad
# plt.subplot(2, 2, 4)
# logs_df['date'] = logs_df['timestamp'].dt.date
# pivot_table = pd.crosstab(logs_df['date'], logs_df['severidad'])
# pivot_table.plot(kind='bar', stacked=True, colormap='viridis')
# plt.title('Eventos por Día y Severidad')
# plt.xlabel('Fecha')
# plt.ylabel('Número de Eventos')
# plt.xticks(rotation=45)
#
# plt.tight_layout()
# plt.savefig('security_dashboard.png')
#
# # Crear gráfico de actividad sospechosa
# plt.figure(figsize=(12, 6))
#
# # 5. Mapa de calor de actividad por hora y tipo de evento
# logs_df['hour'] = logs_df['timestamp'].dt.hour
# heatmap_data = pd.crosstab(logs_df['hour'], logs_df['evento'])
# sns.heatmap(heatmap_data, cmap='YlOrRd', annot=True, fmt='d', cbar_kws={'label': 'Número de Eventos'})
# plt.title('Eventos por Hora y Tipo')
# plt.xlabel('Tipo de Evento')
# plt.ylabel('Hora del Día')
# plt.tight_layout()
# plt.savefig('activity_heatmap.png')
#
# # 6. Análisis de accesos fallidos por usuario
# plt.figure(figsize=(10, 6))
# failed_logins = logs_df[(logs_df['evento'] == 'login_failure') & (logs_df['exitoso'] == False)]
# user_failures = failed_logins['usuario'].value_counts()
# sns.barplot(x=user_failures.index.fillna('anónimo'), y=user_failures.values)
# plt.title('Intentos de Login Fallidos por Usuario')
# plt.xlabel('Usuario')
# plt.ylabel('Número de Intentos Fallidos')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.savefig('failed_logins_by_user.png')
#
# # 7. Línea de tiempo de eventos críticos
# plt.figure(figsize=(12, 4))
# critical_events = logs_df[logs_df['severidad'] == 'critical']
# plt.scatter(critical_events['timestamp'], [1]*len(critical_events), c='red', s=100)
# plt.yticks([])
# plt.title('Línea de Tiempo de Eventos Críticos')
# plt.xlabel('Fecha y Hora')
# plt.tight_layout()
# plt.savefig('critical_events_timeline.png')
#
# print("Visualizaciones generadas correctamente. Revisa los archivos .png generados.")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generar 500 registros de logs simulados
np.random.seed(42)

# Lista de eventos de seguridad
eventos = ['login_success', 'login_failure', 'file_access', 'admin_login', 
           'password_change', 'firewall_block', 'suspicious_activity', 
           'malware_detected', 'port_scan']

# %%
print(eventos)
# Out:
# ['login_success', 'login_failure', 'file_access', 'admin_login', 'password_change', 'firewall_block', 'suspicious_activity', 'malware_detected', 'port_scan']

# %%
# Generar timestamps para una semana
fechas = pd.date_range(start='2023-01-01', periods=7)
timestamps = []
for fecha in fechas:
    for hora in range(24):
        for _ in range(3):  # 3 eventos por hora aprox
            timestamps.append(fecha + pd.Timedelta(hours=hora) + 
                             pd.Timedelta(minutes=np.random.randint(60)))

# %%
print(fechas)
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
print(timestamps)
# Out:
# [Timestamp('2023-01-01 00:38:00'), Timestamp('2023-01-01 00:51:00'), Timestamp('2023-01-01 00:28:00'), Timestamp('2023-01-01 01:14:00'), Timestamp('2023-01-01 01:42:00'), Timestamp('2023-01-01 01:07:00'), Timestamp('2023-01-01 02:20:00'), Timestamp('2023-01-01 02:38:00'), Timestamp('2023-01-01 02:57:00'), Timestamp('2023-01-01 03:18:00'), Timestamp('2023-01-01 03:22:00'), Timestamp('2023-01-01 03:10:00'), Timestamp('2023-01-01 04:10:00'), Timestamp('2023-01-01 04:23:00'), Timestamp('2023-01-01 04:52:00'), Timestamp('2023-01-01 05:35:00'), Timestamp('2023-01-01 05:39:00'), Timestamp('2023-01-01 05:23:00'), Timestamp('2023-01-01 06:02:00'), Timestamp('2023-01-01 06:21:00'), Timestamp('2023-01-01 06:52:00'), Timestamp('2023-01-01 07:01:00'), Timestamp('2023-01-01 07:23:00'), Timestamp('2023-01-01 07:43:00'), Timestamp('2023-01-01 08:29:00'), Timestamp('2023-01-01 08:37:00'), Timestamp('2023-01-01 08:01:00'), Timestamp('2023-01-01 09:59:00'), Timestamp('2023-01-01 09:20:00'), Timestamp('2023-01-01 09:32:00'), Timestamp('2023-01-01 10:11:00'), Timestamp('2023-01-01 10:57:00'), Timestamp('2023-01-01 10:21:00'), Timestamp('2023-01-01 11:43:00'), Timestamp('2023-01-01 11:24:00'), Timestamp('2023-01-01 11:48:00'), Timestamp('2023-01-01 12:26:00'), Timestamp('2023-01-01 12:58:00'), Timestamp('2023-01-01 12:41:00'), Timestamp('2023-01-01 13:27:00'), Timestamp('2023-01-01 13:59:00'), Timestamp('2023-01-01 13:15:00'), Timestamp('2023-01-01 14:14:00'), Timestamp('2023-01-01 14:46:00'), Timestamp('2023-01-01 14:50:00'), Timestamp('2023-01-01 15:43:00'), Timestamp('2023-01-01 15:54:00'), Timestamp('2023-01-01 15:51:00'), Timestamp('2023-01-01 16:56:00'), Timestamp('2023-01-01 16:02:00'), Timestamp('2023-01-01 16:36:00'), Timestamp('2023-01-01 17:50:00'), Timestamp('2023-01-01 17:06:00'), Timestamp('2023-01-01 17:20:00'), Timestamp('2023-01-01 18:08:00'), Timestamp('2023-01-01 18:38:00'), Timestamp('2023-01-01 18:17:00'), Timestamp('2023-01-01 19:03:00'), Timestamp('2023-01-01 19:24:00'), Timestamp('2023-01-01 19:59:00'), Timestamp('2023-01-01 20:13:00'), Timestamp('2023-01-01 20:49:00'), Timestamp('2023-01-01 20:57:00'), Timestamp('2023-01-01 21:08:00'), Timestamp('2023-01-01 21:25:00'), Timestamp('2023-01-01 21:52:00'), Timestamp('2023-01-01 22:01:00'), Timestamp('2023-01-01 22:19:00'), Timestamp('2023-01-01 22:27:00'), Timestamp('2023-01-01 23:46:00'), Timestamp('2023-01-01 23:59:00'), Timestamp('2023-01-01 23:06:00'), Timestamp('2023-01-02 00:43:00'), Timestamp('2023-01-02 00:07:00'), Timestamp('2023-01-02 00:46:00'), Timestamp('2023-01-02 01:34:00'), Timestamp('2023-01-02 01:13:00'), Timestamp('2023-01-02 01:16:00'), Timestamp('2023-01-02 02:35:00'), Timestamp('2023-01-02 02:49:00'), Timestamp('2023-01-02 02:39:00'), Timestamp('2023-01-02 03:03:00'), Timestamp('2023-01-02 03:01:00'), Timestamp('2023-01-02 03:05:00'), Timestamp('2023-01-02 04:53:00'), Timestamp('2023-01-02 04:41:00'), Timestamp('2023-01-02 04:03:00'), Timestamp('2023-01-02 05:53:00'), Timestamp('2023-01-02 05:28:00'), Timestamp('2023-01-02 05:17:00'), Timestamp('2023-01-02 06:25:00'), Timestamp('2023-01-02 06:43:00'), Timestamp('2023-01-02 06:33:00'), Timestamp('2023-01-02 07:09:00'), Timestamp('2023-01-02 07:35:00'), Timestamp('2023-01-02 07:13:00'), Timestamp('2023-01-02 08:30:00'), Timestamp('2023-01-02 08:47:00'), Timestamp('2023-01-02 08:14:00'), Timestamp('2023-01-02 09:07:00'), Timestamp('2023-01-02 09:13:00'), Timestamp('2023-01-02 09:22:00'), Timestamp('2023-01-02 10:59:00'), Timestamp('2023-01-02 10:56:00'), Timestamp('2023-01-02 10:39:00'), Timestamp('2023-01-02 11:20:00'), Timestamp('2023-01-02 11:15:00'), Timestamp('2023-01-02 11:44:00'), Timestamp('2023-01-02 12:17:00'), Timestamp('2023-01-02 12:46:00'), Timestamp('2023-01-02 12:52:00'), Timestamp('2023-01-02 13:23:00'), Timestamp('2023-01-02 13:25:00'), Timestamp('2023-01-02 13:24:00'), Timestamp('2023-01-02 14:59:00'), Timestamp('2023-01-02 14:59:00'), Timestamp('2023-01-02 14:59:00'), Timestamp('2023-01-02 ...

# %%
# Ajustar al número de registros deseados
timestamps = timestamps[:500]

# Generar IPs aleatorias
def random_ip():
    return f"{np.random.randint(1, 256)}.{np.random.randint(1, 256)}.{np.random.randint(1, 256)}.{np.random.randint(1, 256)}"

# Usuarios del sistema
usuarios = ['admin', 'user1', 'user2', 'user3', 'system', 'guest', None]

# Generar datos simulados
data = {
    'timestamp': timestamps,
    'ip_origen': [random_ip() for _ in range(500)],
    'evento': np.random.choice(eventos, 500, p=[0.3, 0.2, 0.2, 0.05, 0.05, 0.08, 0.07, 0.03, 0.02]),
    'usuario': np.random.choice(usuarios, 500, p=[0.1, 0.2, 0.2, 0.2, 0.1, 0.1, 0.1]),
    'severidad': np.random.choice(['low', 'medium', 'high', 'critical'], 500, p=[0.5, 0.3, 0.15, 0.05]),
    'exitoso': np.random.choice([True, False], 500, p=[0.8, 0.2]),
}

# %%
len(timestamps)
# Out:
# 500

# %%
print(usuarios)
# Out:
# ['admin', 'user1', 'user2', 'user3', 'system', 'guest', None]

# %%
print(data)
# Out:
# {'timestamp': [Timestamp('2023-01-01 00:38:00'), Timestamp('2023-01-01 00:51:00'), Timestamp('2023-01-01 00:28:00'), Timestamp('2023-01-01 01:14:00'), Timestamp('2023-01-01 01:42:00'), Timestamp('2023-01-01 01:07:00'), Timestamp('2023-01-01 02:20:00'), Timestamp('2023-01-01 02:38:00'), Timestamp('2023-01-01 02:57:00'), Timestamp('2023-01-01 03:18:00'), Timestamp('2023-01-01 03:22:00'), Timestamp('2023-01-01 03:10:00'), Timestamp('2023-01-01 04:10:00'), Timestamp('2023-01-01 04:23:00'), Timestamp('2023-01-01 04:52:00'), Timestamp('2023-01-01 05:35:00'), Timestamp('2023-01-01 05:39:00'), Timestamp('2023-01-01 05:23:00'), Timestamp('2023-01-01 06:02:00'), Timestamp('2023-01-01 06:21:00'), Timestamp('2023-01-01 06:52:00'), Timestamp('2023-01-01 07:01:00'), Timestamp('2023-01-01 07:23:00'), Timestamp('2023-01-01 07:43:00'), Timestamp('2023-01-01 08:29:00'), Timestamp('2023-01-01 08:37:00'), Timestamp('2023-01-01 08:01:00'), Timestamp('2023-01-01 09:59:00'), Timestamp('2023-01-01 09:20:00'), Timestamp('2023-01-01 09:32:00'), Timestamp('2023-01-01 10:11:00'), Timestamp('2023-01-01 10:57:00'), Timestamp('2023-01-01 10:21:00'), Timestamp('2023-01-01 11:43:00'), Timestamp('2023-01-01 11:24:00'), Timestamp('2023-01-01 11:48:00'), Timestamp('2023-01-01 12:26:00'), Timestamp('2023-01-01 12:58:00'), Timestamp('2023-01-01 12:41:00'), Timestamp('2023-01-01 13:27:00'), Timestamp('2023-01-01 13:59:00'), Timestamp('2023-01-01 13:15:00'), Timestamp('2023-01-01 14:14:00'), Timestamp('2023-01-01 14:46:00'), Timestamp('2023-01-01 14:50:00'), Timestamp('2023-01-01 15:43:00'), Timestamp('2023-01-01 15:54:00'), Timestamp('2023-01-01 15:51:00'), Timestamp('2023-01-01 16:56:00'), Timestamp('2023-01-01 16:02:00'), Timestamp('2023-01-01 16:36:00'), Timestamp('2023-01-01 17:50:00'), Timestamp('2023-01-01 17:06:00'), Timestamp('2023-01-01 17:20:00'), Timestamp('2023-01-01 18:08:00'), Timestamp('2023-01-01 18:38:00'), Timestamp('2023-01-01 18:17:00'), Timestamp('2023-01-01 19:03:00'), Timestamp('2023-01-01 19:24:00'), Timestamp('2023-01-01 19:59:00'), Timestamp('2023-01-01 20:13:00'), Timestamp('2023-01-01 20:49:00'), Timestamp('2023-01-01 20:57:00'), Timestamp('2023-01-01 21:08:00'), Timestamp('2023-01-01 21:25:00'), Timestamp('2023-01-01 21:52:00'), Timestamp('2023-01-01 22:01:00'), Timestamp('2023-01-01 22:19:00'), Timestamp('2023-01-01 22:27:00'), Timestamp('2023-01-01 23:46:00'), Timestamp('2023-01-01 23:59:00'), Timestamp('2023-01-01 23:06:00'), Timestamp('2023-01-02 00:43:00'), Timestamp('2023-01-02 00:07:00'), Timestamp('2023-01-02 00:46:00'), Timestamp('2023-01-02 01:34:00'), Timestamp('2023-01-02 01:13:00'), Timestamp('2023-01-02 01:16:00'), Timestamp('2023-01-02 02:35:00'), Timestamp('2023-01-02 02:49:00'), Timestamp('2023-01-02 02:39:00'), Timestamp('2023-01-02 03:03:00'), Timestamp('2023-01-02 03:01:00'), Timestamp('2023-01-02 03:05:00'), Timestamp('2023-01-02 04:53:00'), Timestamp('2023-01-02 04:41:00'), Timestamp('2023-01-02 04:03:00'), Timestamp('2023-01-02 05:53:00'), Timestamp('2023-01-02 05:28:00'), Timestamp('2023-01-02 05:17:00'), Timestamp('2023-01-02 06:25:00'), Timestamp('2023-01-02 06:43:00'), Timestamp('2023-01-02 06:33:00'), Timestamp('2023-01-02 07:09:00'), Timestamp('2023-01-02 07:35:00'), Timestamp('2023-01-02 07:13:00'), Timestamp('2023-01-02 08:30:00'), Timestamp('2023-01-02 08:47:00'), Timestamp('2023-01-02 08:14:00'), Timestamp('2023-01-02 09:07:00'), Timestamp('2023-01-02 09:13:00'), Timestamp('2023-01-02 09:22:00'), Timestamp('2023-01-02 10:59:00'), Timestamp('2023-01-02 10:56:00'), Timestamp('2023-01-02 10:39:00'), Timestamp('2023-01-02 11:20:00'), Timestamp('2023-01-02 11:15:00'), Timestamp('2023-01-02 11:44:00'), Timestamp('2023-01-02 12:17:00'), Timestamp('2023-01-02 12:46:00'), Timestamp('2023-01-02 12:52:00'), Timestamp('2023-01-02 13:23:00'), Timestamp('2023-01-02 13:25:00'), Timestamp('2023-01-02 13:24:00'), Timestamp('2023-01-02 14:59:00'), Timestamp('2023-01-02 14:59:00'), Timestamp('2023-01-02 14:59:00'), Timesta ...
#        'file_access', 'login_success', 'login_failure', 'file_access',
#        'login_success', 'login_failure', 'login_success', 'login_success',
#        'login_failure', 'login_success', 'file_access', 'file_access',
#        'firewall_block', 'login_success', 'login_success',
#        'login_success', 'file_access', 'admin_login', 'login_success',
#        'suspicious_activity', 'login_success', 'file_access',
#        'admin_login', 'firewall_block', 'admin_login', 'firewall_block',
#        'login_failure', 'firewall_block', 'login_success',
#        'suspicious_activity', 'file_access', 'firewall_block',
#        'login_failure', 'file_access', 'file_access', 'admin_login',
#        'login_success', 'login_success', 'login_success', 'login_success',
#        'firewall_block', 'login_success', 'malware_detected',
#        'login_failure', 'login_success', 'password_change', 'file_access',
#        'login_failure', 'file_access', 'admin_login', 'login_success',
#        'port_scan', 'malware_detected', 'file_access', 'login_success',
#        'file_access', 'login_success', 'login_success', 'login_success',
#        'login_failure', 'firewall_block', 'admin_login', 'admin_login',
#        'login_failure', 'login_failure', 'login_failure', 'port_scan',
#        'login_success', 'firewall_block', 'file_access', 'login_failure',
#        'admin_login', 'login_failure', 'firewall_block',
#        'suspicious_activity', 'login_failure', 'login_success',
#        'file_access', 'suspicious_activity', 'login_success',
#        'file_access', 'file_access', 'admin_login', 'login_success',
#        'admin_login', 'suspicious_activity', 'login_success',
#        'login_success', 'malware_detected', 'login_success',
#        'firewall_block', 'login_failure', 'login_success',
#        'firewall_block', 'login_failure', 'file_access', 'login_failure',
#        'file_access', 'login_success', 'login_failure',
#        'malware_detected', 'login_success', 'file_access',
#        'login_failure', 'password_change', 'login_success',
#        'malware_detected', 'login_failure', 'login_success',
#        'login_success', 'login_success', 'file_access', 'login_failure',
#        'firewall_block', 'login_failure', 'login_success', 'file_access',
#        'admin_login', 'login_success', 'login_success', 'login_success',
#        'admin_login', 'file_access', 'login_failure', 'firewall_block',
#        'firewall_block', 'file_access', 'firewall_block', 'login_success',
#        'login_success', 'login_success', 'login_success', 'file_access',
#        'suspicious_activity', 'login_success', 'login_success',
#        'login_failure', 'suspicious_activity', 'login_failure',
#        'file_access', 'login_success', 'login_success', 'port_scan',
#        'malware_detected', 'login_success', 'malware_detected',
#        'file_access', 'firewall_block', 'login_failure', 'file_access',
#        'login_failure', 'file_access', 'login_success', 'login_success',
#        'login_failure', 'admin_login', 'login_success', 'file_access',
#        'malware_detected', 'login_success', 'file_access',
#        'login_failure', 'firewall_block', 'login_success', 'file_access',
#        'firewall_block', 'suspicious_activity', 'file_access',
#        'login_failure', 'file_access', 'firewall_block', 'file_access',
#        'login_success', 'suspicious_activity', 'file_access',
#        'file_access', 'login_success', 'file_access', 'login_failure',
#        'file_access', 'login_success', 'file_access', 'port_scan',
#        'login_success', 'malware_detected', 'login_failure',
#        'firewall_block', 'password_change', 'file_access', 'admin_login',
#        'firewall_block', 'login_failure', 'login_failure', 'file_access',
#        'firewall_block', 'password_change', 'password_change',
#        'login_failure', 'firewall_block', 'login_success', 'file_access',
#        'login_success', 'login_failure', 'login_failure', 'login_failure',
#        'file_access', 'login_failure', 'login_failure', 'login_success',
#        'login_failure', 'login_success', 'login_success', 'file_access',
#        'file_access', 'file_access', 'login_failure', 'login_failure',
#        'firewall_block', 'file_access', 'login_failure', 'login_success',
#        'login_failure', 'login_failure', 'login_failure', 'file_access',
#        'file_access', 'file_access', 'password_change', 'firewall_block',
#        'admin_login', 'malware_detected', 'login_success',
#        'login_success', 'login_success', 'file_access',
#        'suspicious_activity', 'login_success', 'suspicious_activity',
#        'login_success', 'suspicious_activity', 'login_failure',
#        'login_success', 'login_failure', 'login_success', 'login_success',
#        'login_failure', 'firewall_block', 'file_access', 'login_failure',
#        'file_access', 'admin_login', 'login_success', 'login_failure',
#        'login_success', 'login_success', 'file_access', 'login_success',
#        'file_access', 'admin_login', 'login_success', 'file_access',
#        'login_success', 'malware_detected', 'login_failure',
#        'firewall_block', 'file_access', 'login_success', 'file_access',
#        'malware_detected', 'file_access', 'firewall_block',
#        'suspicious_activity', 'login_success', 'login_success',
#        'file_access', 'login_failure', 'firewall_block',
#        'suspicious_activity', 'login_failure', 'login_success',
#        'password_change', 'login_success', 'firewall_block',
#        'login_failure', 'file_access', 'login_success', 'file_access',
#        'login_failure', 'file_access', 'login_success', 'admin_login',
#        'firewall_block', 'login_success', 'login_success',
#        'login_success', 'file_access', 'file_access', 'file_access',
#        'login_success', 'login_failure', 'file_access', 'login_failure',
#        'port_scan', 'login_success', 'file_access', 'login_failure',
#        'login_failure', 'admin_login', 'file_access', 'port_scan',
#        'login_success', 'login_success', 'admin_login', 'file_access',
#        'login_success', 'login_success', 'login_success',
#        'suspicious_activity', 'login_success', 'login_failure',
#        'login_success', 'login_failure', 'login_success', 'file_access',
#        'login_success', 'firewall_block', 'login_success', 'file_access',
#        'suspicious_activity', 'file_access', 'file_access',
#        'login_failure', 'login_failure', 'file_access', 'port_scan',
#        'file_access', 'file_access', 'admin_login', 'login_failure',
#        'login_success', 'file_access', 'malware_detected',
#        'login_success', 'file_access', 'login_success', 'file_access',
#        'login_success', 'login_failure', 'password_change',
#        'login_failure', 'file_access', 'password_change',
#        'suspicious_activity', 'login_success', 'login_failure',
#        'login_success', 'port_scan', 'suspicious_activity', 'file_access',
#        'firewall_block', 'file_access', 'file_access', 'login_success',
#        'password_change', 'login_success', 'firewall_block',
#        'password_change', 'admin_login', 'login_success', 'login_failure',
#        'login_success', 'login_failure', 'login_success',
#        'suspicious_activity', 'file_access', 'login_failure',
#        'login_failure', 'login_failure', 'file_access', 'file_access',
#        'suspicious_activity', 'login_failure', 'port_scan',
#        'firewall_block', 'login_success', 'suspicious_activity',
#        'login_success', 'firewall_block', 'login_failure',
#        'firewall_block', 'firewall_block', 'firewall_block',
#        'password_change', 'login_failure', 'login_success',
#        'login_failure', 'login_success', 'file_access', 'login_failure',
#        'malware_detected', 'file_access', 'firewall_block',
#        'login_success', 'firewall_block', 'suspicious_activity',
#        'login_failure', 'file_access', 'password_change', 'login_success',
#        'file_access', 'login_failure', 'login_success', 'login_failure',
#        'login_success', 'login_success', 'login_success',
#        'malware_detected', 'file_access', 'malware_detected',
#        'login_failure', 'login_failure', 'file_access', 'login_failure',
#        'login_success', 'file_access', 'login_success', 'file_access',
#        'file_access', 'login_success', 'login_success', 'password_change',
#        'login_failure', 'login_success', 'port_scan', 'login_success',
#        'file_access', 'port_scan', 'login_success', 'login_success',
#        'login_success', 'login_failure', 'login_success', 'file_access',
#        'login_success', 'file_access', 'port_scan', 'firewall_block',
#        'file_access', 'login_failure', 'file_access', 'file_access',
#        'login_failure', 'login_success', 'suspicious_activity',
#        'login_failure', 'login_success', 'login_failure', 'login_failure',
#        'firewall_block', 'admin_login', 'password_change',
#        'login_success', 'login_failure', 'login_failure', 'login_success',
#        'login_success', 'password_change', 'login_success', 'file_access',
#        'login_success', 'login_success', 'login_success',
#        'malware_detected', 'firewall_block', 'malware_detected',
#        'login_failure', 'login_success', 'file_access', 'login_failure',
#        'firewall_block', 'login_success', 'login_failure',
#        'login_success', 'login_failure', 'admin_login', 'login_failure',
#        'login_failure', 'login_failure', 'login_failure',
#        'password_change', 'suspicious_activity', 'malware_detected',
#        'password_change', 'login_failure', 'file_access', 'login_failure'],
#       dtype='<U19'), 'usuario': array(['user1', 'guest', 'admin', None, 'user2', 'user3', 'user3',
#        'guest', 'user3', 'user3', 'admin', 'user3', 'user1', 'system',
#        'user3', 'user3', 'admin', 'admin', 'system', 'admin', 'admin',
#        'admin', None, 'system', 'user2', 'user1', 'user2', 'system',
#        'user3', 'user1', 'user1', 'admin', 'user3', 'system', 'user1',
#        'admin', 'admin', None, 'user1', 'system', 'user3', 'user2',
#        'user1', 'user1', 'user3', 'system', 'user3', 'user3', 'admin',
#        None, 'system', 'user1', None, 'user3', 'user3', 'system', 'guest',
#        'user3', 'user1', 'user2', None, 'user1', 'user2', 'user2',
#        'user2', 'user3', None, 'user1', 'user1', 'user1', 'guest',
#        'user3', 'user1', 'guest', 'guest', 'guest', None, 'user1',
#        'system', 'user2', 'guest', 'system', 'system', 'user3', 'user1',
#        'user3', None, None, 'admin', 'user1', 'user1', 'system', 'guest',
#        'user1', 'user3', 'guest', 'system', 'user3', 'user3', 'user3',
#        'user1', 'user3', 'user3', 'guest', 'user3', 'system', 'user1',
#        'user2', 'admin', 'user1', 'system', None, 'admin', 'user2',
#        'guest', 'user1', 'user3', 'system', 'user3', 'user1', 'user2',
#        'system', 'user3', 'admin', 'system', 'admin', 'system', 'user1',
#        None, 'user2', 'user2', 'user1', 'user2', 'guest', None, 'user2',
#        'user2', 'system', 'guest', 'user3', 'user2', 'user2', 'user3',
#        'admin', 'user3', 'user2', 'system', 'admin', 'user3', 'user2',
#        'user3', 'admin', 'user3', 'user3', 'user3', 'user3', 'user3',
#        'guest', 'user1', 'guest', 'user2', 'admin', 'admin', 'user2',
#        'system', 'system', 'system', 'user3', 'user2', 'user1', 'user2',
#        'user2', 'admin', 'user1', 'user3', 'system', None, None, 'user3',
#        'user2', 'user3', 'system', 'user1', 'user2', 'guest', 'user2',
#        'user3', 'user3', 'user1', 'user2', 'user2', 'admin', 'admin',
#        'guest', 'user1', 'user3', 'user1', None, 'user1', 'user2',
#        'guest', 'guest', 'user1', 'guest', 'user2', 'user2', 'user1',
#        'admin', 'system', 'user2', 'user2', 'system', 'system', 'user1',
#        'user3', 'user1', 'system', 'user3', None, 'admin', 'admin',
#        'user1', 'user1', 'user1', None, 'user1', 'user1', 'system',
#        'user2', 'system', 'admin', 'user2', 'admin', 'admin', None,
#        'user1', 'user3', 'user2', 'user2', 'guest', 'admin', 'user3',
#        None, 'user3', None, 'admin', 'user2', 'user1', 'system', None,
#        'user1', 'user3', 'user1', 'user3', 'user2', None, 'user3',
#        'user2', 'user1', 'user1', 'user1', 'user1', 'guest', 'user3',
#        'user3', 'user1', 'guest', 'system', 'admin', 'system', 'user3',
#        'admin', 'user2', 'user2', 'user1', None, 'guest', 'user3',
#        'user2', 'user2', 'user3', 'user3', 'admin', 'user3', 'guest',
#        'user2', 'admin', 'system', 'user1', 'user1', 'user1', 'user2',
#        'system', 'user3', 'user1', 'guest', 'guest', 'guest', 'user1',
#        'user2', None, 'system', 'admin', 'admin', 'user2', None, 'user3',
#        'user2', 'user1', 'user3', 'guest', 'user2', 'system', None,
#        'user1', 'user3', 'user1', 'system', 'user3', 'user3', 'system',
#        'user2', None, 'user3', 'user1', 'user3', 'system', 'user2',
#        'guest', None, 'user1', None, 'user1', 'user1', 'user1', 'guest',
#        'user3', 'user1', 'user2', 'user3', 'admin', 'guest', 'guest',
#        'user3', None, 'user2', None, 'user3', 'user3', 'user1', 'guest',
#        'user2', 'user1', 'admin', 'user3', 'user3', 'system', 'guest',
#        'admin', 'system', 'user1', 'guest', 'guest', 'user3', 'system',
#        'user2', 'user2', 'guest', 'user2', 'user2', 'user2', 'guest',
#        'user2', 'user1', 'system', 'guest', 'user1', 'user1', 'user1',
#        'user2', 'user2', 'system', 'user3', 'user3', 'user2', 'guest',
#        'user2', None, 'user3', 'user1', 'user3', 'user2', 'user3',
#        'admin', 'user1', 'guest', 'user1', 'guest', 'user1', 'user3',
#        'user3', 'user3', 'user2', 'user1', 'admin', 'user2', 'user3',
#        None, 'guest', 'system', 'system', 'user3', 'user1', None, 'user3',
#        'user3', 'user1', 'user2', 'user2', 'guest', 'user3', 'user2',
#        None, 'user1', 'user2', 'admin', 'system', None, 'user1', 'guest',
#        'user1', None, 'system', 'guest', 'admin', None, 'system', 'user2',
#        'guest', 'user1', 'guest', 'user1', 'system', 'user3', 'admin',
#        'user1', 'admin', 'user2', 'user2', 'user3', 'user1', 'user1',
#        'system', 'admin', None, 'guest', 'user3', 'user3', 'guest',
#        'user1', 'admin', 'user1', 'system', 'admin', 'user3', None,
#        'guest', 'user3', 'admin', 'guest', 'user3', 'user1', 'admin',
#        None, 'user3', 'guest', 'guest', 'user3', 'user3', 'user2',
#        'user2', 'user2', 'system', 'user3', 'guest', 'user2', 'user3',
#        'user3', 'user3', 'system', 'user1', 'user3', 'user1', 'user2',
#        'user2', 'user3', None, 'user3', 'system', 'user3'], dtype=object), 'severidad': array(['medium', 'low', 'low', 'low', 'low', 'low', 'low', 'low',
#        'critical', 'low', 'low', 'low', 'medium', 'low', 'low', 'medium',
#        'low', 'low', 'low', 'low', 'low', 'low', 'high', 'medium',
#        'medium', 'low', 'high', 'low', 'low', 'medium', 'low', 'low',
#        'medium', 'high', 'low', 'medium', 'critical', 'low', 'low', 'low',
#        'low', 'low', 'high', 'medium', 'medium', 'low', 'high',
#        'critical', 'high', 'low', 'medium', 'low', 'low', 'low', 'medium',
#        'medium', 'low', 'low', 'low', 'low', 'low', 'low', 'medium',
#        'low', 'low', 'low', 'high', 'medium', 'medium', 'low', 'medium',
#        'low', 'medium', 'high', 'medium', 'high', 'medium', 'low', 'high',
#        'low', 'medium', 'low', 'low', 'low', 'low', 'low', 'medium',
#        'low', 'low', 'medium', 'low', 'medium', 'medium', 'high',
#        'medium', 'low', 'medium', 'low', 'low', 'medium', 'low', 'medium',
#        'high', 'high', 'high', 'low', 'low', 'medium', 'low', 'medium',
#        'medium', 'medium', 'low', 'low', 'low', 'low', 'high', 'low',
#        'low', 'low', 'medium', 'medium', 'low', 'low', 'low', 'low',
#        'medium', 'medium', 'low', 'low', 'critical', 'low', 'medium',
#        'low', 'low', 'low', 'medium', 'critical', 'low', 'low', 'low',
#        'low', 'low', 'low', 'medium', 'low', 'low', 'high', 'low',
#        'critical', 'low', 'high', 'medium', 'high', 'critical', 'low',
#        'critical', 'low', 'low', 'low', 'medium', 'low', 'medium',
#        'medium', 'medium', 'high', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'critical', 'medium', 'low', 'medium', 'low', 'low',
#        'medium', 'low', 'low', 'critical', 'high', 'medium', 'medium',
#        'medium', 'low', 'low', 'low', 'low', 'medium', 'low', 'critical',
#        'high', 'medium', 'medium', 'high', 'low', 'medium', 'low',
#        'medium', 'low', 'high', 'high', 'low', 'low', 'critical', 'low',
#        'high', 'medium', 'low', 'low', 'low', 'medium', 'low', 'medium',
#        'low', 'medium', 'high', 'critical', 'low', 'high', 'medium',
#        'medium', 'critical', 'low', 'low', 'high', 'low', 'high', 'high',
#        'low', 'high', 'low', 'medium', 'medium', 'high', 'low', 'low',
#        'medium', 'medium', 'medium', 'low', 'low', 'low', 'high', 'low',
#        'low', 'critical', 'low', 'critical', 'medium', 'high', 'low',
#        'low', 'medium', 'high', 'medium', 'low', 'medium', 'medium',
#        'medium', 'medium', 'high', 'medium', 'low', 'low', 'low', 'low',
#        'low', 'low', 'low', 'low', 'high', 'high', 'low', 'critical',
#        'medium', 'low', 'low', 'medium', 'medium', 'medium', 'low', 'low',
#        'low', 'low', 'low', 'low', 'high', 'high', 'low', 'high', 'low',
#        'low', 'low', 'medium', 'critical', 'medium', 'low', 'medium',
#        'low', 'high', 'medium', 'low', 'medium', 'medium', 'low',
#        'medium', 'low', 'medium', 'high', 'high', 'medium', 'medium',
#        'low', 'medium', 'low', 'low', 'low', 'low', 'medium', 'low',
#        'medium', 'low', 'low', 'medium', 'low', 'low', 'medium', 'low',
#        'high', 'low', 'low', 'medium', 'low', 'low', 'low', 'low', 'high',
#        'low', 'medium', 'high', 'low', 'high', 'low', 'critical', 'low',
#        'medium', 'low', 'low', 'medium', 'medium', 'low', 'low', 'medium',
#        'medium', 'critical', 'medium', 'critical', 'medium', 'low', 'low',
#        'medium', 'medium', 'low', 'low', 'critical', 'medium', 'low',
#        'low', 'low', 'low', 'low', 'low', 'medium', 'low', 'high', 'high',
#        'low', 'medium', 'low', 'high', 'low', 'medium', 'medium', 'low',
#        'low', 'medium', 'medium', 'low', 'medium', 'low', 'medium', 'low',
#        'high', 'low', 'low', 'low', 'low', 'medium', 'low', 'high', 'low',
#        'low', 'low', 'low', 'low', 'low', 'low', 'low', 'medium',
#        'medium', 'low', 'low', 'critical', 'medium', 'medium', 'low',
#        'medium', 'medium', 'medium', 'critical', 'low', 'low', 'medium',
#        'high', 'low', 'low', 'low', 'low', 'medium', 'medium', 'low',
#        'low', 'low', 'low', 'medium', 'critical', 'high', 'low', 'high',
#        'medium', 'medium', 'low', 'low', 'low', 'low', 'low', 'low',
#        'low', 'medium', 'low', 'low', 'critical', 'high', 'medium',
#        'critical', 'medium', 'critical', 'low', 'low', 'low', 'low',
#        'low', 'medium', 'medium', 'medium', 'low', 'high', 'medium',
#        'low', 'medium', 'low', 'low', 'high', 'low', 'low', 'high',
#        'medium', 'low', 'low', 'low', 'medium', 'low', 'low', 'critical',
#        'medium', 'low', 'medium', 'medium', 'low', 'low', 'high', 'low',
#        'medium', 'low', 'low', 'low'], dtype='<U8'), 'exitoso': array([ True,  True,  True, False, False,  True, False,  True, False,
#         True, False, False,  True, False,  True,  True,  True,  True,
#         True,  True, False,  True,  True, False, False, False,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True, False,  True, False,  True,  True,  True,  True,  True,
#         True,  True, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True, False,
#         True,  True, False, False,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#        False,  True,  True, False, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False,  True,  True,  True, False,  True,  True, False,
#         True, False,  True,  True,  True, False, False,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True, False,  True,  True,  True, False,  True,
#        False,  True,  True,  True, False,  True, False,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#        False, False,  True,  True, False,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#        False,  True,  True, False,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False, False, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True, False,
#        False,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True, False,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False,  True])}

# %%
# Crear DataFrame
logs_df = pd.DataFrame(data)

# Configurar timestamp como índice
logs_df['timestamp'] = pd.to_datetime(logs_df['timestamp'])
logs_df = logs_df.sort_values('timestamp')

# Ahora creamos las visualizaciones
plt.figure(figsize=(15, 10))

# %%
# 1. Distribución de eventos por tipo
plt.subplot(2, 2, 1)
eventos_count = logs_df['evento'].value_counts()
sns.barplot(x=eventos_count.index, y=eventos_count.values)
plt.xticks(rotation=45, ha='right')
plt.title('Distribución de Eventos por Tipo')
plt.tight_layout()

# %%
# 2. Distribución de eventos por severidad
plt.subplot(2, 2, 2)
severidad_count = logs_df['severidad'].value_counts()
colors = {'low': 'green', 'medium': 'blue', 'high': 'orange', 'critical': 'red'}
plt.pie(severidad_count, labels=severidad_count.index, autopct='%1.1f%%',
        colors=[colors[sev] for sev in severidad_count.index])
plt.title('Distribución de Eventos por Severidad')
# Out:
# Text(0.5, 1.0, 'Distribución de Eventos por Severidad')

# %%
logs_df
# Out:
#               timestamp        ip_origen            evento usuario severidad  \
# 2   2023-01-01 00:28:00   115.215.143.92       file_access   admin       low
# 0   2023-01-01 00:38:00      173.20.65.8     login_success   user1    medium
# 1   2023-01-01 00:51:00  238.144.142.204     login_failure   guest       low
# 5   2023-01-01 01:07:00   186.63.190.125     login_success   user3       low
# 3   2023-01-01 01:14:00     98.66.32.215       admin_login    None       low
# ..                  ...              ...               ...     ...       ...
# 497 2023-01-07 21:23:00   102.169.136.11     login_failure   user3       low
# 496 2023-01-07 21:24:00    45.217.33.252   password_change    None    medium
# 495 2023-01-07 21:49:00     95.166.32.11  malware_detected   user3       low
# 498 2023-01-07 22:12:00    214.179.88.41       file_access  system       low
# 499 2023-01-07 22:59:00    145.76.121.46     login_failure   user3       low
#
#      exitoso  hour
# 2       True     0
# 0       True     0
# 1       True     0
# 5       True     1
# 3      False     1
# ..       ...   ...
# 497    False    21
# 496    False    21
# 495     True    21
# 498    False    22
# 499     True    22
#
# [500 rows x 7 columns]

# %%
severidad_count
# Out:
# severidad
# low         268
# medium      142
# high         61
# critical     29
# Name: count, dtype: int64

# %%
# 3. Actividad por hora del día
plt.subplot(2, 2, 3)
logs_df['hour'] = logs_df['timestamp'].dt.hour
hourly_count = logs_df.groupby('hour').size()
sns.lineplot(x=hourly_count.index, y=hourly_count.values)
plt.title('Actividad por Hora del Día')
plt.xlabel('Hora')
plt.ylabel('Número de Eventos')
# Out:
# Text(0, 0.5, 'Número de Eventos')

# %%
# 4. Eventos por día y por severidad
plt.subplot(2, 2, 4)
logs_df['date'] = logs_df['timestamp'].dt.date
pivot_table = pd.crosstab(logs_df['date'], logs_df['severidad'])
pivot_table.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Eventos por Día y Severidad')
plt.xlabel('Fecha')
plt.ylabel('Número de Eventos')
plt.xticks(rotation=45)

plt.tight_layout()
plt.savefig('security_dashboard.png')

# Crear gráfico de actividad sospechosa
plt.figure(figsize=(12, 6))

# %%
logs_df
# Out:
#               timestamp        ip_origen            evento usuario severidad  \
# 2   2023-01-01 00:28:00   115.215.143.92       file_access   admin       low
# 0   2023-01-01 00:38:00      173.20.65.8     login_success   user1    medium
# 1   2023-01-01 00:51:00  238.144.142.204     login_failure   guest       low
# 5   2023-01-01 01:07:00   186.63.190.125     login_success   user3       low
# 3   2023-01-01 01:14:00     98.66.32.215       admin_login    None       low
# ..                  ...              ...               ...     ...       ...
# 497 2023-01-07 21:23:00   102.169.136.11     login_failure   user3       low
# 496 2023-01-07 21:24:00    45.217.33.252   password_change    None    medium
# 495 2023-01-07 21:49:00     95.166.32.11  malware_detected   user3       low
# 498 2023-01-07 22:12:00    214.179.88.41       file_access  system       low
# 499 2023-01-07 22:59:00    145.76.121.46     login_failure   user3       low
#
#      exitoso  hour        date
# 2       True     0  2023-01-01
# 0       True     0  2023-01-01
# 1       True     0  2023-01-01
# 5       True     1  2023-01-01
# 3      False     1  2023-01-01
# ..       ...   ...         ...
# 497    False    21  2023-01-07
# 496    False    21  2023-01-07
# 495     True    21  2023-01-07
# 498    False    22  2023-01-07
# 499     True    22  2023-01-07
#
# [500 rows x 8 columns]

# %%
pivot_table
# Out:
# severidad   critical  high  low  medium
# date
# 2023-01-01         3     7   45      17
# 2023-01-02         2     8   40      22
# 2023-01-03         7    10   36      19
# 2023-01-04         5    13   33      21
# 2023-01-05         3    10   36      23
# 2023-01-06         4     6   41      21
# 2023-01-07         5     7   37      19

# %%
# 5. Mapa de calor de actividad por hora y tipo de evento
logs_df['hour'] = logs_df['timestamp'].dt.hour
heatmap_data = pd.crosstab(logs_df['hour'], logs_df['evento'])
sns.heatmap(heatmap_data, cmap='YlOrRd', annot=True, fmt='d', cbar_kws={'label': 'Número de Eventos'})
plt.title('Eventos por Hora y Tipo')
plt.xlabel('Tipo de Evento')
plt.ylabel('Hora del Día')
plt.tight_layout()
plt.savefig('activity_heatmap.png')

# %%
# 6. Análisis de accesos fallidos por usuario
plt.figure(figsize=(10, 6))
failed_logins = logs_df[(logs_df['evento'] == 'login_failure') & (logs_df['exitoso'] == False)]
user_failures = failed_logins['usuario'].value_counts()
sns.barplot(x=user_failures.index.fillna('anónimo'), y=user_failures.values)
plt.title('Intentos de Login Fallidos por Usuario')
plt.xlabel('Usuario')
plt.ylabel('Número de Intentos Fallidos')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('failed_logins_by_user.png')

# %%
# 7. Línea de tiempo de eventos críticos
plt.figure(figsize=(12, 4))
critical_events = logs_df[logs_df['severidad'] == 'critical']
plt.scatter(critical_events['timestamp'], [1]*len(critical_events), c='red', s=100)
plt.yticks([])
plt.title('Línea de Tiempo de Eventos Críticos')
plt.xlabel('Fecha y Hora')
plt.tight_layout()
plt.savefig('critical_events_timeline.png')

print("Visualizaciones generadas correctamente. Revisa los archivos .png generados.")
# Out:
# Visualizaciones generadas correctamente. Revisa los archivos .png generados.
